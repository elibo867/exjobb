# %%
import sys 
import re
import numpy as np

# %%
def extract_score(filename):
    f=open(filename,'r')
    text=f.read()
    
    #get GDT_TS_score
    GDT_TS_match=re.search('GDT-TS-score=\s(\d.\d\d\d\d)',text)
    try:
        score=float(GDT_TS_match.group(1))
        return score
    
    except Exception as e:
        print (e)
        return 'No GDT_TS-score in TM file'

# %%
def main(argv): 

    filename=argv
    scores=extract_score(filename)
    
           
    #scores_array=np.asarray(scores) 
    
    #np.savez_compressed('y_train_3', scores)
    
    return scores
    
if __name__ == '__main__':
    main(sys.argv)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-13b6acfd33b5> in <module>()
#       7
#       8
# ----> 9 main()
#
# <ipython-input-7-13b6acfd33b5> in main()
#       3     scores=[]
#       4     for filename in filenames:
# ----> 5         extract_score(filename)
#       6         #score.append(extract_score(filename))
#       7
#
# <ipython-input-6-3638d0527048> in extract_score(filename)
#       1 def extract_score(filename):
# ----> 2     f=open(filename,'r')
#       3     text=f.read
#       4
#       5     #get GDT_TS_score
#
# IOError: [Errno 2] No such file or directory: '-f'
